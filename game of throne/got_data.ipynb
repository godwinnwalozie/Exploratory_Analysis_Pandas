# %%
import pandas as pd
import numpy as np
from datetime import datetime, time, date
from dateutil import parser
import matplotlib.pyplot as plt
import seaborn as sns

# %%
got =pd.read_csv(r'Ads Data Revenue.csv')

# %%
got.sort_values( 'Impressions', ascending = False)
# Out:
#      Campaign ID      Timestamp       Date InventoryType   Ad Type  \
# 959       122958  2014-09-08-16   9/8/2014       Format3  Inter221
# 398       122397  2014-09-06-22   9/6/2014       Format3  inter230
# 729       122728  2014-09-10-02  9/10/2014       Format4  Inter225
# 905       122904  2014-09-08-07   9/8/2014       Format5  Inter223
# 620       122619  2014-09-09-22   9/9/2014       Format3  Inter221
# ..           ...            ...        ...           ...       ...
# 126       122125  2014-09-06-16   9/6/2014       Format3  Inter224
# 446       122445  2014-09-07-02   9/7/2014       Format1  inter230
# 621       122620  2014-09-10-16  9/10/2014       Format3  Inter222
# 31        122030  2014-09-06-15   9/6/2014       Format3  Inter218
# 568       122567  2014-09-07-00   9/7/2014       Format5  Inter222
#
#     Available_Impressions Matched_Queries Impressions  Clicks      Spend  Fee  \
# 959             2,714,334       1,077,683     999,848   5,832  $1,639.33  35%
# ...

# %%
got.Spend.replace('\$|,' , '', regex = True, inplace = True) 
got.Impressions.replace('\$|,' , '', regex = True, inplace = True)
got.Clicks.replace('\$|,' , '', regex = True, inplace = True)
got.Revenue.replace('\$|,' , '', regex = True, inplace = True)
got.Fee.replace('\%' ,  '' , regex = True , inplace = True)

# %%
got.Fee.sample(10)
# Out:
# 309    35
# 565    35
# 793    35
# 549    35
# 895    35
# 942    35
# 348    23
# 853    21
# 660    35
# 308    35
# Name: Fee, dtype: object

# %%
got.rename({'Revenue' :'Revenue'}, axis = 1)
# Out:
#       Campaign ID      Timestamp      Date InventoryType   Ad Type  \
# 0          121999  2014-09-05-03  9/5/2014       Format6  Inter219
# 1          122000  2014-09-05-08  9/5/2014       Format4  Inter220
# 2          122001  2014-09-05-16  9/5/2014       Format4  Inter221
# 3          122002  2014-09-05-01  9/5/2014       Format1  Inter218
# 4          122003  2014-09-05-10  9/5/2014       Format4  Inter222
# ...           ...            ...       ...           ...       ...
# 996        122995  2014-09-08-01  9/8/2014       Format3  Inter229
# 997        122996  2014-09-07-18  9/7/2014       Format4  Inter225
# 998        122997  2014-09-07-21  9/7/2014       Format3  inter230
# 999        122998  2014-09-08-09  9/8/2014       Format5  Inter220
# 1000       122999  2014-09-08-09  9/8/2014       Format3  Inter217
#
#      Available_Impressions Matched_Queries Impressions Clicks    Spend Fee  \
# 0                    4,015           2,217         581     81    11.57  35
# ...

# %%
# got.to_csv('rev_data_got.csv')

# %%
got.Date = pd.to_datetime(got['Date'])

# %%
got.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Campaign ID            1001 non-null   int64
#  1   Timestamp              1001 non-null   object
#  2   Date                   1001 non-null   datetime64[ns]
#  3   InventoryType          1001 non-null   object
#  4   Ad Type                1001 non-null   object
#  5   Available_Impressions  1001 non-null   object
#  6   Matched_Queries        1001 non-null   object
#  7   Impressions            1001 non-null   object
#  8   Clicks                 1001 non-null   object
#  9   Spend                  1001 non-null   object
#  10  Fee                    1001 non-null   object
#  11  Revenue                1001 non-null   object
#  12  CTR                    1001 non-null   object
#  13  CPM                    1001 non-null   object
# ...

# %%
pd.to_datetime('May 23 2019')
# Out:
# Timestamp('2019-05-23 00:00:00')

# %%
parser.parse('May 21 2019')
# Out:
# datetime.datetime(2019, 5, 21, 0, 0)

# %%
dater = ['2019/12/01' , '2022/02/01']
timer = ['12:02' , '07:23']

# %%
chest = pd.DataFrame(dater, timer).rename({0 : 'date'}, axis = 1)
chest = chest.reset_index().rename({'index' :'time'}, axis = 1).reindex(['date','time'], axis = 1)
chest
# Out:
#          date   time
# 0  2019/12/01  12:02
# 1  2022/02/01  07:23

# %%
got['Campaign ID'].nunique()
# Out:
# 1001

# %%
got.shape
# Out:
# (1001, 15)
