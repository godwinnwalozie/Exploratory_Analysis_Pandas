# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, date, time
from dateutil import parser

# %%
pd.read_csv(r'national_family_health_survey.csv')
# Out:
#      Unnamed: 0              District Names                   State/UT  \
# 0             0                    Nicobars  Andaman & Nicobar Islands
# 1             1     North & Middle Andaman   Andaman & Nicobar Islands
# 2             2              South Andaman   Andaman & Nicobar Islands
# 3             3                 Srikakulam              Andhra Pradesh
# 4             4               Vizianagaram              Andhra Pradesh
# ..          ...                         ...                        ...
# 701         701                    Kolkata                 West Bengal
# 702         702  South Twenty Four Pargana                 West Bengal
# 703         703          Paschim Medinipur                 West Bengal
# 704         704            Purba Medinipur                 West Bengal
# 705         705         Paschim Barddhaman                 West Bengal
#
#      Number of Households surveyed  \
# 0                              882
# 1                              874
# ...
