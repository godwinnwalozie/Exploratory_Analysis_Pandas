# %% [markdown]
# # Data Science -  Business Challenge
# # Government Agency - Analysis of Consumer complaint from Financial Institution

# %%
import numpy as np

# %%
import pandas as pd
import qgrid

# %% [markdown]
# # Importing the csv file that houses the dataset
# # see csv files in the folder

# %%
consumer = pd.read_csv(r'C:\Users\godwi\GitHub\Python-Pandas\Government Agency\P9-ConsumerComplaints.csv',\
low_memory=False)

# %%
consumer.sample(10) # selecting 10 rows to validate data
# Out:
#       Date Received             Product Name  \
# 33191     7/12/2014         Credit reporting
# 3079      9/12/2013  Bank account or service
# 3454       9/9/2013                 Mortgage
# 1889       8/5/2013                 Mortgage
# 26528     4/11/2014         Credit reporting
# 8280     10/25/2013         Credit reporting
# 303       7/31/2013                 Mortgage
# 38033     8/21/2014  Bank account or service
# 5540      8/28/2013         Credit reporting
# 11753    11/30/2013          Debt collection
#
#                                  Sub Product  \
# 33191                                    NaN
# 3079                        Checking account
# 3454             Conventional fixed mortgage
# 1889                          Other mortgage
# 26528                                    NaN
# 8280                                     NaN
# 303                           Other mortgage
# 38033             Other bank product/service
# 5540                                     NaN
# 11753  Other (i.e. phone, health club, etc.)
#
#                                           Issue         Sub Issue  \
# 33191    Incorrect information on credit report    Account status
# 3079    Account opening, closing, or management               NaN
# 3454   Loan modification,collection,foreclosure               NaN
# 1889               Settlement process and costs               NaN
# 26528    Incorrect information on credit report    Account status
# 8280     Incorrect information on credit report    Account status
# 303    Loan modification,collection,foreclosure               NaN
# 38033   Account opening, closing, or management               NaN
# 5540     Incorrect information on credit report     Public record
# 11753     Cont'd attempts collect debt not owed  Debt is not mine
#
#       Consumer Complaint Narrative Company Public Response  \
# 33191                          NaN                     NaN
# 3079                           NaN                     NaN
# 3454                           NaN                     NaN
# 1889                           NaN                     NaN
# 26528                          NaN                     NaN
# 8280                           NaN                     NaN
# 303                            NaN                     NaN
# 38033                          NaN                     NaN
# 5540                           NaN                     NaN
# 11753                          NaN                     NaN
#
#                                       Company State Name Zip Code  \
# 33191  TransUnion Intermediate Holdings, Inc.         PR      674
# 3079               TD Bank US Holding Company         NY    11415
# 3454                          Bank of America         AZ    85225
# 1889                     SunTrust Banks, Inc.         FL    32250
# 26528                                 Equifax         KY    40203
# 8280                                 Experian         NY    11218
# 303                      JPMorgan Chase & Co.         CA    92656
# 38033                   Wells Fargo & Company         CA    91615
# 5540                                 Experian         GA    31419
# 11753                      EOS Holdings, Inc.         KY    41017
#
#                  Tags Consumer Consent Provided Submitted via  \
# 33191             NaN                       NaN           Web
# 3079              NaN                       NaN      Referral
# 3454              NaN                       NaN           Web
# 1889              NaN                       NaN      Referral
# 26528             NaN                       NaN      Referral
# 8280              NaN                       NaN           Web
# 303               NaN                       NaN      Referral
# 38033             NaN                       NaN         Phone
# 5540    Servicemember                       NaN   Postal mail
# 11753  Older American                       NaN           Web
#
#       Date Sent to Company     Company Response to Consumer Timely Response  \
# 33191            7/12/2014          Closed with explanation             Yes
# 3079             9/13/2013      Closed with monetary relief             Yes
# 3454             9/10/2013  Closed with non-monetary relief             Yes
# 1889              8/7/2013  Closed with non-monetary relief             Yes
# 26528            4/22/2014          Closed with explanation             Yes
# 8280            10/29/2013          Closed with explanation             Yes
# 303               8/5/2013          Closed with explanation             Yes
# 38033            8/26/2014          Closed with explanation             Yes
# 5540             12/4/2013  Closed with non-monetary relief             Yes
# 11753           11/30/2013  Closed with non-monetary relief             Yes
#
#       Consumer Disputed  Complaint ID
# 33191               NaN        934527
# 3079                 No        525486
# 3454                 No        519077
# 1889                 No        474158
# 26528                No        804742
# 8280                 No        572440
# 303                  No        479594
# 38033                No        995406
# 5540                 No        507711
# 11753                No        616528

# %% [markdown]
# # Understanding the data, type, shape

# %%
consumer.info(verbose= False)
# dataset is made up of integers, object types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65499 entries, 0 to 65498
# Columns: 18 entries, Date Received to Complaint ID
# dtypes: int64(1), object(17)
# memory usage: 9.0+ MB

# %%
consumer.shape   
# data has 65499 rows and 18 columns
# Out:
# (65499, 18)

# %% [markdown]
# # The Business -  Question 1 :
# # How many complaint were received and sent on same day

# %%
# Question 1 : # how many complaint were received and sent on same day
received_com_sameday = consumer.loc[:, ['Complaint ID','Date Received','Date Sent to Company']]

# %%
received_com_sameday[received_com_sameday['Date Sent to Company'] ==\
                     received_com_sameday['Date Received']].count()
# 2,8737 complaints were received and sent on same day
# Out:
# Complaint ID            28737
# Date Received           28737
# Date Sent to Company    28737
# dtype: int64

# %% [markdown]
# # The Business -  Question 2 :
# # Extract the complaints received in the state of New York

# %%
# Quetion 2    : # Extract the complaints received in the state of New York
consumer.loc[:, ['Complaint ID','State Name']].head()
# Out:
#    Complaint ID State Name
# 0        468882         VA
# 1        468889         CA
# 2        468879         NY
# 3        468949         GA
# 4        475823         CT

# %%
# Qestion 2    : # Extract the complaints received in the state of New York
# step 1
complaints_NY =consumer.loc[:,['Complaint ID', 'Company','State Name','Date Received','Date Sent to Company'] ]

# %%
# Qestion 2    : # Extract the complaints received in the state of New York
# step 2
complaints_NY[complaints_NY['State Name'] == 'NY'].head(5)
# Out:
#     Complaint ID                Company State Name Date Received  \
# 2         468879      Santander Bank US         NY     7/29/2013
# 15        469057   JPMorgan Chase & Co.         NY     7/29/2013
# 17        469070   JPMorgan Chase & Co.         NY     7/29/2013
# 23        480173  Wells Fargo & Company         NY     7/29/2013
# 24        469360                  Ocwen         NY     7/29/2013
#
#    Date Sent to Company
# 2             7/31/2013
# 15            7/31/2013
# 17            7/30/2013
# 23            7/31/2013
# 24            7/30/2013

# %% [markdown]
# # The Business -  Question 3 :
# # Extract the complaints received in the state of New York and California

# %%
# Qestion 3    : # Extract the complaints received in the state of New York amnd California
# step 2
complaints_NY[(complaints_NY['State Name'] == 'NY') | (complaints_NY['State Name'] == 'CA')]
# Out:
#        Complaint ID                Company State Name Date Received  \
# 1            468889  Wells Fargo & Company         CA     7/29/2013
# 2            468879      Santander Bank US         NY     7/29/2013
# 11           469284   JPMorgan Chase & Co.         CA     7/29/2013
# 12           480488               Citibank         CA     7/29/2013
# 15           469057   JPMorgan Chase & Co.         NY     7/29/2013
# ...             ...                    ...        ...           ...
# 65483       1362371  Wells Fargo & Company         CA      5/6/2015
# 65490       1385061  PayPal Holdings, Inc.         CA     5/20/2015
# 65492       1363172                  Ocwen         CA      5/6/2015
# 65495       1364367        Bank of America         CA      5/6/2015
# 65497       1363039             Afni, Inc.         CA      5/6/2015
#
#       Date Sent to Company
# 1                7/31/2013
# 2                7/31/2013
# 11               7/30/2013
# 12               7/31/2013
# 15               7/31/2013
# ...                    ...
# 65483             5/7/2015
# 65490            5/20/2015
# 65492             5/7/2015
# 65495             5/7/2015
# 65497             5/7/2015
#
# [13668 rows x 5 columns]

# %% [markdown]
# # The Business -  Question 4 :
# # Extract the rows with the word 'credit in product field'

# %%
# Question 4  Extract the rows with the word 'credit in product field'
consumer[consumer['Product Name'].str.contains('Credit',case= False)].head()
# Out:
#    Date Received      Product Name Sub Product  \
# 8      7/29/2013       Credit card         NaN
# 19     7/29/2013       Credit card         NaN
# 20     7/29/2013  Credit reporting         NaN
# 28     7/29/2013  Credit reporting         NaN
# 37     7/29/2013       Credit card         NaN
#
#                                        Issue  \
# 8                          Billing statement
# 19                      APR or interest rate
# 20  Credit monitoring or identity protection
# 28    Incorrect information on credit report
# 37                        Delinquent account
#
#                                 Sub Issue Consumer Complaint Narrative  \
# 8                                     NaN                          NaN
# 19                                    NaN                          NaN
# 20  Problem cancelling or closing account                          NaN
# 28                          Public record                          NaN
# 37                                    NaN                          NaN
#
#    Company Public Response              Company State Name Zip Code Tags  \
# 8                      NaN             Citibank         OH    45247  NaN
# 19                     NaN  Synchrony Financial         WA    98548  NaN
# 20                     NaN             Experian         CA    90034  NaN
# 28                     NaN              Equifax         CA    91605  NaN
# 37                     NaN                 Amex         TX    78232  NaN
#
#    Consumer Consent Provided Submitted via Date Sent to Company  \
# 8                        NaN      Referral            7/30/2013
# 19                       NaN           Web            7/29/2013
# 20                       NaN           Web            7/29/2013
# 28                       NaN           Web            7/29/2013
# 37                       NaN           Web            7/29/2013
#
#        Company Response to Consumer Timely Response Consumer Disputed  \
# 8           Closed with explanation             Yes               Yes
# 19      Closed with monetary relief             Yes                No
# 20      Closed with monetary relief             Yes                No
# 28  Closed with non-monetary relief             Yes                No
# 37      Closed with monetary relief             Yes                No
#
#     Complaint ID
# 8         469026
# 19        469131
# 20        474204
# 28        469201
# 37        479990

# %% [markdown]
# # The Business -  Question 5 :
# # Extract the rows with the word 'late in issues field'

# %%
consumer[consumer['Issue'].str.contains('Late',case= False)].head()
# Out:
#      Date Received Product Name Sub Product     Issue Sub Issue  \
# 199      7/31/2013  Credit card         NaN  Late fee       NaN
# 400      7/23/2013  Credit card         NaN  Late fee       NaN
# 477       8/7/2013  Credit card         NaN  Late fee       NaN
# 1010     8/14/2013  Credit card         NaN  Late fee       NaN
# 1313     8/14/2013  Credit card         NaN  Late fee       NaN
#
#      Consumer Complaint Narrative Company Public Response  \
# 199                           NaN                     NaN
# 400                           NaN                     NaN
# 477                           NaN                     NaN
# 1010                          NaN                     NaN
# 1313                          NaN                     NaN
#
#                    Company State Name Zip Code Tags Consumer Consent Provided  \
# 199   JPMorgan Chase & Co.         IL    60201  NaN                       NaN
# 400            Capital One         AR    72015  NaN                       NaN
# 477               Citibank         CA    94523  NaN                       NaN
# 1010              Citibank         TX    75024  NaN                       NaN
# 1313       Bank of America         NY    10024  NaN                       NaN
#
#      Submitted via Date Sent to Company Company Response to Consumer  \
# 199            Web            7/31/2013  Closed with monetary relief
# 400            Web            7/23/2013  Closed with monetary relief
# 477            Web             8/7/2013  Closed with monetary relief
# 1010           Web            8/14/2013  Closed with monetary relief
# 1313           Web            8/20/2013  Closed with monetary relief
#
#      Timely Response Consumer Disputed  Complaint ID
# 199              Yes                No        471204
# 400              Yes                No        463829
# 477              Yes                No        488956
# 1010             Yes                No        492046
# 1313             Yes                No        492446
