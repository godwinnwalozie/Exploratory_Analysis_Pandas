# %%
import opendatasets as od
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
grade = pd.read_csv(r'student_clustering.csv')
grade.head()
# Out:
#    cgpa   iq
# 0  5.13   88
# 1  5.90  113
# 2  8.36   93
# 3  8.27   97
# 4  5.45  110

# %%
# check datatypes
grade.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cgpa    200 non-null    float64
#  1   iq      200 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 3.2 KB

# %%
# check shape
grade.shape
# Out:
# (200, 2)

# %%
# check relationship between cgpa and IQ
#scatterd plot with seaborn
sns.relplot(data = grade , x = 'cgpa' , y = 'iq');

# %%
grade.iq.corr(grade.cgpa)
# Out:
# 0.53530070926363

# %%
# using matplotlib
grade.plot(kind = 'scatter' , x = 'iq', y = 'cgpa', figsize = (7,7))
# Out:
# <AxesSubplot:xlabel='iq', ylabel='cgpa'>

# %%
# check distribution
sns.displot(grade, x = 'cgpa' , kde = 'True');

# %%
# check distribution
sns.displot(grade, x = 'cgpa' , kind = 'kde');
