# %% [markdown]
# # Nigerian Graduate Report 2018 by Stutern

# %%
import numpy as np
import pandas as pd
import datetime

# %%
nig_grad= pd.read_csv\
(r'C:\Users\godwi\OneDrive\Documents\Data Science\GitHub\Python-Pandas\Nigeria Graduate Report 2018\Nigerian Graduates Destination Survey.csv')
nig_grad.head()
# Out:
#          Timestamp What is your gender  Year of graduation  \
# 0    2/8/2018 9:05                Male                2013
# 1  2/15/2018 12:11                Male                2014
# 2  2/15/2018 13:47              Female                2013
# 3  2/16/2018 13:01                Male                2017
# 4  2/16/2018 13:18              Female                2013
#
#                              Title of course studied  \
# 0                Electrical & Electronic Engineering
# 1                                         Psychology
# 2                                          Economics
# 3  Mass Communication (Communication and Language...
# 4                                         Statistics
#
#         Polytechnic/University attended  \
# 0    Obafemi Awolowo University,Ile-Ife
# 1    Obafemi Awolowo University,Ile-Ife
# 2  Bells University of Technology, Otta
# 3                 Bowen University, Iwo
# 4                Ekiti State University
#
# ...

# %%
nig_grad.shape
# Out:
# (5219, 36)

# %%
nig_grad.info(verbose = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5219 entries, 0 to 5218
# Columns: 36 entries, Timestamp to Which of these skills/knowledge did your higher education prepare you for?
# dtypes: float64(2), int64(2), object(32)
# memory usage: 1.4+ MB

# %%
# find out the count of male vs female on the survey
nig_grad_gender = nig_grad['What is your gender'].value_counts().to_frame()
nig_grad_gender
# Out:
#                    What is your gender
# Male                              2624
# Female                            2592
# Prefer not to say                    3

# %%
# what percentage of female is the sample
female_perc = nig_grad_gender.iloc[1,0] / ( nig_grad_gender.iloc[0,0] +\
        nig_grad_gender.iloc[1,0] + nig_grad_gender.iloc[2,0]) * 100
female_perc = round(female_perc,2)
female_perc = print(str(female_perc) + ' %')
# Out:
# 49.66 %

# %%
# what percentage of male is the sample
male_perc = nig_grad_gender.iloc[0,0] / ( nig_grad_gender.iloc[0,0] +\
        nig_grad_gender.iloc[1,0] + nig_grad_gender.iloc[2,0]) * 100
male_perc = round(male_perc,2)
male_perc = print(str(male_perc) + ' %')
# Out:
# 50.28 %

# %%
# which year had the largest graduates
nig_grad['Year of graduation'].value_counts().to_frame()\
.sort_values('Year of graduation', ascending = False)
# Out:
#       Year of graduation
# 2015                1327
# 2017                1259
# 2016                1214
# 2014                 824
# 2013                 595

# %%
# which school had the highest graduate
nig_grad['Polytechnic/University attended'].value_counts().to_frame()
# Out:
#                                                     Polytechnic/University attended
# University of Lagos                                                             527
# Covenant University Ota                                                         432
# Obafemi Awolowo University,Ile-Ife                                              326
# Babcock University,Ilishan-Remo                                                 213
# University of Nigeria, Nsukka                                                   208
# ...                                                                             ...
# Grace Polytechnic, Surulere, Lagos State.                                         1
# Wellspring University, Evbuobanosa - Edo State                                    1
# Ignatius Ajuru University of Education,Rumuolum...                                1
# Heritage Polytechnic, Ikot Udota, Eket, Akwa Ib...                                1
# ...

# %%
# what is the highest level of degree by 
grad_degree = nig_grad.loc[:, ['What is your highest level of education?','What is your gender','Timestamp']].\
groupby(['What is your highest level of education?','What is your gender']).\
count().rename({'Timestamp' : 'count'},axis = 1)

# %%
grad_degree.unstack()
# Out:
#                                            count
# What is your gender                       Female    Male Prefer not to say
# What is your highest level of education?
# Bachelor's degree                         2241.0  2158.0               3.0
# Higher National Diploma (HND)              158.0   210.0               NaN
# MBA degree                                  11.0     9.0               NaN
# Master's degree                            115.0   191.0               NaN
# Ordinary National Diploma (OND)             63.0    53.0               NaN
# PhDs/Doctorate Degree                        4.0     3.0               NaN

# %%
# completed NYSC?
nig_grad.loc[:,['Have you completed your NYSC?','What is your gender']]\
.value_counts().to_frame().rename({0 : 'count'},axis = 1).unstack()
# Out:
#                                 count
# What is your gender            Female    Male Prefer not to say
# Have you completed your NYSC?
# No                              558.0   463.0               2.0
# Ongoing                         415.0   362.0               NaN
# Yes                            1619.0  1798.0               1.0

# %%
nig_grad[nig_grad.isna().values].drop_duplicates().head()
# Out:
#          Timestamp What is your gender  Year of graduation  \
# 0    2/8/2018 9:05                Male                2013
# 1  2/15/2018 12:11                Male                2014
# 2  2/15/2018 13:47              Female                2013
# 3  2/16/2018 13:01                Male                2017
# 7   2/19/2018 8:40                Male                2015
#
#                              Title of course studied  \
# 0                Electrical & Electronic Engineering
# 1                                         Psychology
# 2                                          Economics
# 3  Mass Communication (Communication and Language...
# 7                                        Accountancy
#
#         Polytechnic/University attended  \
# 0    Obafemi Awolowo University,Ile-Ife
# 1    Obafemi Awolowo University,Ile-Ife
# 2  Bells University of Technology, Otta
# 3                 Bowen University, Iwo
# 7    Obafemi Awolowo University,Ile-Ife
#
# ...

# %%
from pandas_visual_analysis import VisualAnalysis
